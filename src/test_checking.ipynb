# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'E:\Multimodal-Customer-Insight-And-Retention-Engine\data\sample_multimodal_data.csv')

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
#
#   order_status                             review_comment_message  \
# 0    delivered  Não testei o produto ainda, mas ele veio corre...
# 1    delivered  Não testei o produto ainda, mas ele veio corre...
# 2    delivered  Não testei o produto ainda, mas ele veio corre...
# 3    delivered                               Muito bom o produto.
# 4    delivered  O produto foi exatamente o que eu esperava e e...
#
#    review_score   price  freight_value  payment_value  product_category_name
# ...

# %%
df.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_status              0
# review_comment_message    0
# review_score              0
# price                     0
# freight_value             0
# product_category_name     3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                500 non-null    str
#  1   customer_id             500 non-null    str
#  2   order_status            500 non-null    str
#  3   review_comment_message  500 non-null    str
#  4   review_score            500 non-null    float64
#  5   price                   500 non-null    float64
#  6   freight_value           500 non-null    float64
#  7   product_category_name   497 non-null    str
# dtypes: float64(3), str(5)
# memory usage: 31.4 KB

# %%
print(df['product_category_name'].nunique())
# Out:
# 47

# %%
df.describe()
# Out:
#        review_score       price  freight_value
# count    500.000000   500.00000     500.000000
# mean       3.420000   121.01622      20.308640
# std        1.651986   200.39122      17.079104
# min        1.000000     6.00000       0.000000
# 25%        1.000000    39.90000      12.790000
# 50%        4.000000    74.94500      16.080000
# 75%        5.000000   125.00000      21.955000
# max        5.000000  2690.00000     145.990000

# %%
num_columns = df[['review_score','price','freight_value']]

# %%
df.duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
plt.figure(figsize=(10,6))
plt.boxplot(num_columns)
plt.show()
